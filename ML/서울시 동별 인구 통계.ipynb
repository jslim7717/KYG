# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('2023년 인구.csv', encoding='utf-8')
df
# Out:
#     동별(1)     항목 2023 1/4 2023 1/4.1 2023 1/4.2 2023 1/4.3 2023 1/4.4  \
# 0   동별(1)     항목       합계       0~4세       5~9세     10~14세     15~19세
# 1      합계      계  9668008     227792     318362     364760     393817
# 2      합계    한국인  9426404     223600     312530     360436     388258
# 3      합계  등록외국인   241604       4192       5832       4324       5559
# 4     종로구      계   152212       2599       3960       4908       5827
# ..    ...    ...      ...        ...        ...        ...        ...
# 74    송파구    한국인   658006      18628      26754      29356      28759
# 75    송파구  등록외국인     5698         94        138         83         67
# 76    강동구      계   464027      13721      18584      20133      19173
# 77    강동구    한국인   459982      13649      18478      20043      19095
# 78    강동구  등록외국인     4045         72        106         90         78
#
#    2023 1/4.5 2023 1/4.6 2023 1/4.7  ... 2023 4/4.12 2023 4/4.13 2023 4/4.14  \
# ...

# %%
df = pd.read_csv('2023년 인구.csv', header=1, encoding='utf-8')
df
# Out:
#    동별(1)     항목       합계    0~4세    5~9세  10~14세  15~19세  20~24세  25~29세  \
# 0     합계      계  9668008  227792  318362  364760  393817  615813  845503
# 1     합계    한국인  9426404  223600  312530  360436  388258  575672  807658
# 2     합계  등록외국인   241604    4192    5832    4324    5559   40141   37845
# 3    종로구      계   152212    2599    3960    4908    5827   12901   14886
# 4    종로구    한국인   141060    2444    3759    4694    5475    9513   12558
# ..   ...    ...      ...     ...     ...     ...     ...     ...     ...
# 73   송파구    한국인   658006   18628   26754   29356   28759   35557   51153
# 74   송파구  등록외국인     5698      94     138      83      67     276     641
# 75   강동구      계   464027   13721   18584   20133   19173   23872   34222
# 76   강동구    한국인   459982   13649   18478   20043   19095   23678   33712
# 77   강동구  등록외국인     4045      72     106      90      78     194     510
#
#     30~34세  ...  55~59세.3  60~64세.3  65~69세.3  70~74세.3  75~79세.3  80~84세.3  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 90 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   동별(1)      78 non-null     object
#  1   항목         78 non-null     object
#  2   합계         78 non-null     int64
#  3   0~4세       78 non-null     int64
#  4   5~9세       78 non-null     int64
#  5   10~14세     78 non-null     int64
#  6   15~19세     78 non-null     int64
#  7   20~24세     78 non-null     int64
#  8   25~29세     78 non-null     int64
#  9   30~34세     78 non-null     int64
#  10  35~39세     78 non-null     int64
#  11  40~44세     78 non-null     int64
#  12  45~49세     78 non-null     int64
#  13  50~54세     78 non-null     int64
#  14  55~59세     78 non-null     int64
#  15  60~64세     78 non-null     int64
#  16  65~69세     78 non-null     int64
#  17  70~74세     78 non-null     int64
#  18  75~79세     78 non-null     int64
#  19  80~84세     78 non-null     int64
# ...

# %%
df_index=df.set_index(['동별(1)'])
df_index
# Out:
#           항목       합계    0~4세    5~9세  10~14세  15~19세  20~24세  25~29세  30~34세  \
# 동별(1)
# 합계         계  9668008  227792  318362  364760  393817  615813  845503  787893
# 합계       한국인  9426404  223600  312530  360436  388258  575672  807658  763386
# 합계     등록외국인   241604    4192    5832    4324    5559   40141   37845   24507
# 종로구        계   152212    2599    3960    4908    5827   12901   14886   11600
# 종로구      한국인   141060    2444    3759    4694    5475    9513   12558   10652
# ...      ...      ...     ...     ...     ...     ...     ...     ...     ...
# 송파구      한국인   658006   18628   26754   29356   28759   35557   51153   54373
# 송파구    등록외국인     5698      94     138      83      67     276     641     788
# 강동구        계   464027   13721   18584   20133   19173   23872   34222   35473
# 강동구      한국인   459982   13649   18478   20043   19095   23678   33712   34950
# 강동구    등록외국인     4045      72     106      90      78     194     510     523
#
# ...

# %%
df_Seoul=df_index.iloc[0::3,[1]]

# %%
df_Seoul=df_Seoul[1:]
df_Seoul
# Out:
#            합계
# 동별(1)
# 종로구    152212
# 중구     131390
# 용산구    232482
# 성동구    287240
# 광진구    350925
# 동대문구   354884
# 중랑구    389928
# 성북구    441855
# 강북구    296934
# 도봉구    312858
# 노원구    506989
# 은평구    468766
# 서대문구   321966
# 마포구    376542
# 양천구    442345
# 강서구    573711
# 구로구    417983
# 금천구    242467
# 영등포구   398999
# 동작구    390377
# 관악구    502628
# 서초구    408979
# 강남구    537817
# 송파구    663704
# 강동구    464027

# %%
df_Seoul.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 25 entries, 종로구 to 강동구
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   합계      25 non-null     int64
# dtypes: int64(1)
# memory usage: 400.0+ bytes

# %%
import matplotlib.pyplot as plt
plt.rc('font', family = 'Malgun Gothic')

# %%
df_Seoul.plot()
# Out:
# <Axes: xlabel='동별(1)'>

# %%
df_Seoul.plot()
